# %% [markdown]
# # TASK 2

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading CSV file

# %%
train = pd.read_csv("train.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# train.info()

# %% [markdown]
# ## Checking For Null Values

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Formatting the null values

# %%
train.dropna(subset=["Embarked"])
train["Cabin"].fillna("Unknown")
train["Age"].fillna(train["Age"].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.642093
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 889, dtype: float64

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex        Age  \
# 0                             Braund, Mr. Owen Harris    male  22.000000
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# ...

# %% [markdown]
# ## Checking for duplicate values

# %%
print(train.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ## Plotting Age Distribution of Passengers Using Histogram

# %%
plt.figure(figsize=(9,4),facecolor = 'orange',edgecolor = 'black',frameon = "top")
sns.histplot(train["Age"],kde=True)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Plotting Bar Plot for the Survived V/S Not Survived

# %%
survival_counts = df['Survived'].value_counts().sort_index()
labels = ['Not Survived', 'Survived']


figure, axis = plt.subplots()
bars = axis.bar(labels, survival_counts, color=['orange', 'skyblue'],edgecolor = 'black')

# adding the count number inside the bars
for bar, count in zip(bars, survival_counts):
    axis.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() / 2,
        str(count),
        color='black', fontsize=11, fontweight='light'
    )

plt.title('Titanic Survival Counts')
plt.xlabel('Survival Status')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
# ## Plotting The Bar Chart for Male V/s Female for Survived and Not Survived

# %%
survival_by_sex = df.groupby(["Sex", "Survived"]).size().unstack(fill_value=0)
survival_by_sex.plot(kind='bar', stacked=False, color=['red', 'green'])

plt.title("Survival Counts by Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Passengers")
plt.legend(["Not Survived", "Survived"])
plt.xticks(rotation=0)

# Add counts on top of each bar for clarity
for idx, row in enumerate(survival_by_sex.values):
    for i, count in enumerate(row):
        plt.text(idx - 0.15 + i*0.3, count + 5, str(count), ha='center', va='bottom', fontsize=9)
plt.show()

# %% [markdown]
# ## Plotting the scatter flot for comparing the survival rates using the fare price

# %%
plt.figure(figsize=(8, 6))
plt.scatter(train['Survived'], train['Fare'], color='blue')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Fare')
plt.title('Scatter Plot of Survival vs Fare (Titanic Dataset)')
plt.xticks([0 , 1 ])
plt.show()
# It shows that the passenge who has paid more has a greater chance of survival.

# %% [markdown]
# ## Plotting the bar plot for the survival rate for different passenger class

# %%
classwise_survival = train.groupby('Pclass')['Survived'].mean()

classwise_survival.plot(kind='bar', color=['gold', 'silver', 'brown'])
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.xticks([0,1,2], ['1st', '2nd', '3rd'])
plt.ylim(0,1)
plt.show()
